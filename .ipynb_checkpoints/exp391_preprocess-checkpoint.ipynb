# %%
import os
from pathlib import Path
import HuitianPreProcessStuff as hpps

# %%
os.getcwd()
# Out:
# '/mnt/d/Huitian_Practice/NB'

# %%
os.chdir('/mnt/d/Huitian_Practice/exp391')

# %%
os.listdir()
# Out:
# ['1_Scanpy',
#  '1_Scanpy_2',
#  'cache',
#  'cellsorted_possorted_genome_bam.bam',
#  'feature_reference.csv',
#  'filtered_feature_bc_matrix',
#  'Hashtag_count_new',
#  'metrics_summary.csv',
#  'possorted_genome_bam.bam',
#  'web_summary.html']

# %% [markdown]
# set dir

# %%
code_dir = os.getcwd()
wk_dir = code_dir +"/Hashtag_count_new"
Path(wk_dir).mkdir(parents=True, exist_ok=True)
os.chdir(wk_dir)

# %%
wk_dir
# Out:
# '/mnt/d/Huitian_Practice/exp391/Hashtag_count_new'

# %%
sp_name = "exp391"
ft_tsv = code_dir + '/filtered_feature_bc_matrix/features.tsv'
mtx_mtx = code_dir + '/filtered_feature_bc_matrix/matrix.mtx'

hpps.cellAbReads(sp_name,ft_tsv,mtx_mtx)
celltypes = hpps.cellType(sp_name,20,0.9)
# Out:
#    sample  total_cell_number  negative_percentage  doublet_percentage   NWT  \
# 0  exp391              18353                 0.11               21.82  5.13
#
#     C8P    C5P    A5T   A5P   A8T   A8P  NP14B
# 0  5.84  14.04  15.92  15.8  8.71  6.96   5.68
